# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

from sklearn import svm
from sklearn import metrics
import pandas as pd
import numpy as np
data_df =  pd.read_csv('Profesional.csv')
print(data_df)
data_df=data_df.replace('Mujer',0)
data_df=data_df.replace('Hombre',1)
data_df=data_df.replace('Si',0)
data_df=data_df.replace('No',1)
data_df
x=data_df['Ingresos']
y=data_df['Transacciones']
#X = data_df.drop(['target'],axis=1).values   # independant features
#y = data_df['target'].values					# dependant variable
# Out:
#      Edad  Género Compras de bienes raíces  Valor de la inversión $  \
# 0      38   Mujer                       No                     12.2
# 1      30  Hombre                       No                     12.4
# 2      41   Mujer                       No                     26.8
# 3      28   Mujer                       Si                     19.6
# 4      36  Hombre                       Si                     43.0
# ..    ...     ...                      ...                      ...
# 405    32   Mujer                       No                     27.4
# 406    26   Mujer                       Si                     14.4
# 407    24  Hombre                       Si                     36.0
# 408    25   Mujer                       Si                     30.3
# 409    28   Mujer                       Si                     30.5
#
#      Transacciones Internet  Ingresos Hijos
# 0                4       Si      75.2    Si
# 1                4       Si      70.3    Si
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x,
y, test_size=0.6, random_state=109)

# %%
clf = svm.SVC(kernel='linear')

# %%
# train the model

X_train=X_train.values.reshape([X_train.values.shape[0],1])
X_test=X_test.values.reshape([X_test.values.shape[0],1])
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
### Evaluate the model

# Model Accuracy: how often is the classifier correct?
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:", metrics.precision_score(y_test, y_pred, average='weighted'))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:", metrics.recall_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy: 0.13008130081300814
# Precision: 0.016921144821204312
# Recall: 0.13008130081300814
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_test,y_pred,color='red')
